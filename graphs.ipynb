# %% [markdown]
# ### Initialization

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Training Evaluation

# %% [markdown]
# ### Random Agent vs RL Agent

# %%
df = pd.read_csv("random_score.csv")

fig, ax = plt.subplots(figsize=(9, 6))
window_size = 100

ax.plot(df, label="Actual Score")
ax.plot(df.rolling(window_size).mean(), label=f"Moving Average Over {window_size} Episodes")

ax.set_xlabel("Episode")
ax.set_ylabel("Score")
ax.set_title(f"Performance of Random Agent")
ax.legend()

plt.show()
